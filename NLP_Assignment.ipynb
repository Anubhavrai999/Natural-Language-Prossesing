# %% [markdown]
# ### **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing**.

# %%
import spacy

# %%
nlp= spacy.load('en_core_web_sm')

# %%
text='''
 Sikkim's history spans from its Lepcha roots to becoming India's 22nd state,
 marked by the founding of a Buddhist kingdom in 1642 under the Namgyal dynasty,
 its British protectorate status from the 19th century,
 and its eventual integration into India in 1975 following a referendum after a period as an Indian protectorate from 1950.
 Key groups include indigenous Lepchas, Tibetan Bhutias, and Nepali settlers, creating a rich cultural blend,
 while its strategic Himalayan location made it significant for India.
'''

# %%
doc=nlp(text)

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Sikkim           POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# history          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# spans            POS: NOUN        TAG: NNS         DEP: ROOT  Description: noun, plural
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# Lepcha           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# roots            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# becoming         POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# India            POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# 22nd             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# state            POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# marked           POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# founding         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# Buddhist         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# kingdom          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1642             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# under            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Namgyal          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# dynasty          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# British          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# protectorate     POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# status           POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# 19th             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# century          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# eventual         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# integration      POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# into             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1975             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# following        POS: VERB        TAG: VBG         DEP: acl  Description: verb, gerund or present participle
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# referendum       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# after            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# period           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# Indian           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# protectorate     POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1950             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Key              POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# groups           POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# include          POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# indigenous       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Lepchas          POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Tibetan          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Bhutias          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Nepali           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# settlers         POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# creating         POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# rich             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# cultural         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# blend            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# while            POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# strategic        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Himalayan        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# location         POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# made             POS: VERB        TAG: VBD         DEP: advcl  Description: verb, past tense
# it               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# significant      POS: ADJ         TAG: JJ          DEP: ccomp  Description: adjective (English), other noun-modifier (Chinese)
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- Sikkim
# Sikkim       <--poss      -- spans
# 's           <--case      -- Sikkim
# history      <--compound  -- spans
# spans        <--ROOT      -- spans
# from         <--prep      -- spans
# its          <--poss      -- roots
# Lepcha       <--compound  -- roots
# roots        <--pobj      -- from
# to           <--prep      -- spans
# becoming     <--pcomp     -- to
# India        <--poss      -- state
# 's           <--case      -- India
# 22nd         <--amod      -- state
# state        <--attr      -- becoming
# ,            <--punct     -- spans
#
#             <--dep       -- ,
# marked       <--acl       -- spans
# by           <--agent     -- marked
# the          <--det       -- founding
# founding     <--pobj      -- by
# of           <--prep      -- founding
# a            <--det       -- kingdom
# Buddhist     <--amod      -- kingdom
# kingdom      <--pobj      -- of
# in           <--prep      -- founding
# 1642         <--pobj      -- in
# under        <--prep      -- founding
# the          <--det       -- dynasty
# Namgyal      <--compound  -- dynasty
# dynasty      <--pobj      -- under
# ,            <--punct     -- spans
#
#             <--dep       -- ,
# its          <--poss      -- status
# British      <--amod      -- status
# protectorate <--compound  -- status
# status       <--appos     -- spans
# from         <--prep      -- status
# the          <--det       -- century
# 19th         <--amod      -- century
# century      <--pobj      -- from
# ,            <--punct     -- status
#
#             <--dep       -- ,
# and          <--cc        -- status
# its          <--poss      -- integration
# eventual     <--amod      -- integration
# integration  <--conj      -- status
# into         <--prep      -- integration
# India        <--pobj      -- into
# in           <--prep      -- integration
# 1975         <--pobj      -- in
# following    <--acl       -- spans
# a            <--det       -- referendum
# referendum   <--pobj      -- following
# after        <--prep      -- following
# a            <--det       -- period
# period       <--pobj      -- after
# as           <--prep      -- period
# an           <--det       -- protectorate
# Indian       <--amod      -- protectorate
# protectorate <--pobj      -- as
# from         <--prep      -- protectorate
# 1950         <--pobj      -- from
# .            <--punct     -- spans
#
#             <--dep       -- .
# Key          <--amod      -- groups
# groups       <--nsubj     -- include
# include      <--ROOT      -- include
# indigenous   <--amod      -- Lepchas
# Lepchas      <--dobj      -- include
# ,            <--punct     -- Lepchas
# Tibetan      <--compound  -- Bhutias
# Bhutias      <--conj      -- Lepchas
# ,            <--punct     -- Bhutias
# and          <--cc        -- Bhutias
# Nepali       <--compound  -- settlers
# settlers     <--conj      -- Bhutias
# ,            <--punct     -- include
# creating     <--advcl     -- include
# a            <--det       -- blend
# rich         <--amod      -- blend
# cultural     <--amod      -- blend
# blend        <--dobj      -- creating
# ,            <--punct     -- include
#
#             <--dep       -- ,
# while        <--mark      -- made
# its          <--poss      -- location
# strategic    <--amod      -- location
# Himalayan    <--amod      -- location
# location     <--nsubj     -- made
# made         <--advcl     -- include
# it           <--nsubj     -- significant
# significant  <--ccomp     -- made
# for          <--prep      -- significant
# India        <--pobj      -- for
# .            <--punct     -- include
#
#             <--dep       -- .

# %% [markdown]
# ## **Visualization**

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5f13ce390afc4cbb821353437287faf2-0" class="displacy" width="15450" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Sikkim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">history</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">spans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Lepcha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">roots</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">becoming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">22nd</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">state,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">
#  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">marked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">founding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Buddhist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">kingdom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">1642</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Namgyal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">dynasty,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">
#  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="
